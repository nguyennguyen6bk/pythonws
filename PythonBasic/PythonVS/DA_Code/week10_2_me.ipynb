# %%
# Hoi quy
#Consumption ~ Income

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
dataset =  pd.read_csv("data-uschange.csv")
dataset
# Out:
#      Time  Consumption    Income  Production   Savings  Unemployment
# 0       1     0.615986  0.972261   -2.452700  4.810312           0.9
# 1       2     0.460376  1.169085   -0.551525  7.287992           0.5
# 2       3     0.876791  1.553271   -0.358708  7.289013           0.5
# 3       4    -0.274245 -0.255272   -2.185455  0.985230           0.7
# 4       5     1.897371  1.987154    1.909734  3.657771          -0.1
# ..    ...          ...       ...         ...       ...           ...
# 182   183     0.664970  0.801663    0.380606  3.180930          -0.3
# 183   184     0.561680  0.740063   -0.845546  3.482786           0.0
# 184   185     0.404682  0.519025   -0.417930  2.236534           0.0
# 185   186     1.047707  0.723721   -0.203319 -2.721501          -0.1
# 186   187     0.729598  0.644701    0.474918 -0.572858           0.0
#
# [187 rows x 6 columns]
