# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
xpoints = np.array([0, 7])
ypoints = np.array([0, 50])
plt.plot(xpoints,ypoints)
plt.show()
